# %%
import pandas as pd
import time

arquivo1=pd.read_csv("ArmasApreendidasEvolucaoCisp(1)2022.csv", sep=";", encoding="latin-1") #caminhos dos arquivos


inicio_tempo=time.time() #marcação do tempo de processamento
df_pandas=pd.concat([arquivo1])

display(df_pandas.head())

print("Tempo de execução com Pandas:", time.time() - inicio_tempo, "segundos")
# Out:
#   Soma de arma_fogo_total  Rótulos de Coluna   Unnamed: 2
# 0        Rótulos de Linha               2022  Total Geral
# 1                Setembro                515          515
# 2                 Outubro                488          488
# 3                Novembro                598          598
# 4             Total Geral               1601         1601
# Tempo de execução com Pandas: 0.0029997825622558594 segundos

# %%
import pandas as pd
import time

arquivo1=pd.read_csv("ArmasApreendidasEvolucaoCisp(1)2023.csv", sep=";", encoding="latin-1") #caminhos dos arquivos


inicio_tempo=time.time() #marcação do tempo de processamento
df_pandas=pd.concat([arquivo1])

display(df_pandas.head())

print("Tempo de execução com Pandas:", time.time() - inicio_tempo, "segundos")
# Out:
#   Soma de arma_fogo_total  Rótulos de Coluna   Unnamed: 2
# 0        Rótulos de Linha               2023  Total Geral
# 1                Setembro                398          398
# 2                 Outubro                450          450
# 3                Novembro                463          463
# 4             Total Geral               1311         1311
# Tempo de execução com Pandas: 0.0030050277709960938 segundos

# %%
import pandas as pd
import numpy as np

# %%
dados=pd.read_csv('ArmasApreendidasEvolucaoCisp.csv',sep=";")
display(dados.head())
estatistica=dados.describe()
display(estatistica)
df_copia=dados.copy()
# Out:
#    cisp  mes   ano  aisp  risp  arma_fogo_arma_fabricacao_caseira  \
# 0     1    1  2007     5     1                                  0
# 1     1    2  2007     5     1                                  0
# 2     1    3  2007     5     1                                  0
# 3     1    4  2007     5     1                                  0
# 4     1    5  2007     5     1                                  0
#
#    arma_fogo_carabina  arma_fogo_espingarda  arma_fogo_fuzil  \
# 0                   0                     0                0
# 1                   0                     0                0
# 2                   0                     0                0
# 3                   0                     0                0
# 4                   0                     0                0
#
#    arma_fogo_garrucha  ...  simulacro_fuzil  simulacro_garrucha  \
# 0                   0  ...              NaN                 NaN
# 1                   0  ...              NaN                 NaN
# ...
