# %%
import numpy as np
import pandas as pd

# %%
preços=np.array([2500,3200,2700,3000,3400,3700,4500,4700, 5000, 5200, 6000, 7000])
preços
# Out:
# array([2500, 3200, 2700, 3000, 3400, 3700, 4500, 4700, 5000, 5200, 6000,
#        7000])

# %%
media=np.mean(preços)
print(f'Média: {media}')
# Out:
# Média: 4241.666666666667

# %%
#diferenças em relação à média
diferenças=[x - media for x in amostra]
display(diferenças)
# Out:
# [np.float64(-2941.666666666667),
#  np.float64(-1941.666666666667),
#  np.float64(2958.333333333333),
#  np.float64(20000058.333333332),
#  np.float64(3058.333333333333),
#  np.float64(1158.333333333333),
#  np.float64(3158.333333333333),
#  np.float64(1758.333333333333),
#  np.float64(-1741.666666666667),
#  np.float64(3758.333333333333),
#  np.float64(-241.66666666666697)]

# %%
display(preços)
#Numpy - cálculo da variância
variancia=np.var(preços)
print(variancia)
# Out:
# array([2500, 3200, 2700, 3000, 3400, 3700, 4500, 4700, 5000, 5200, 6000,
#        7000])
# 1792430.5555555557

# %%
#Numpy - cálculo do desvio-padrão
desviopadrao=np.std(preços)
print(desviopadrao)
# Out:
# 1338.8168491453773

# %%
#Pandas - cálculo da variância
preços2=pd.Series(preços)
variancia=preços2.var()
print(variancia)
# Out:
# 1955378.787878788

# %%
#Pandas - cálculo do desvio-padrão
desviopadrao=preços2.std()
print(desviopadrao)
# Out:
# 1398.3485931193222

# %%
#coeficiente de variação (CV) é o desvio-padrão dividido pela média
coef_variacao=desviopadrao/media
print(coef_variacao)
# Out:
# 0.3296696093798009

# %%
#cálculo da distância da variância em relação à média
distancia=variancia / (media**2)
print(distancia*100,'%')
# Out:
# 10.868205134863054 %

# %% [markdown]
# Como eu interpreto isso?
#
# 1. distância <= 10%: minha dispersão é BAIXA;
# 2. distância > 10% e <= 25%: minha dispersão é MODERADA;
# 3. distância > 25%: minha dispersão é ALTA.

# %% [markdown]
# ASSIMETRIA
#
#
# É uma medida que nos indica a TENDÊNCIA DA DISTRIBUIÇÃO dos dados para o lado dos valores menores ou maiores.
#  Para obtê-la, utilizamos o método do Pandas chamado skew().
#
#  Como vou interpretar meus dados:
#
#  1. Assimetria >= -0.5 e Assimetria <= 0.5: distribuição SIMÉTRICA (média aproximadamente igual à mediana);
#
#  2. Assimetria > 0.5: distribuição ASSIMÉTRICA POSITIVA (média maior que a mediana; distribuição tendendo mais à direita);
#
#  3. Assimetria < -0.5: distribuição ASSIMÉTRICA NEGATIVA (média menor que a mediana; distribuição tendendo mais à esquerda).

# %%
preços_df=pd.DataFrame(preços, columns=['valores'])
print(modelo_df)
# Out:
#     valores
# 0      2500
# 1      3200
# 2      2700
# 3      3000
# 4      3400
# 5      3700
# 6      4500
# 7      4700
# 8      5000
# 9      5200
# 10     6000
# 11     7000
